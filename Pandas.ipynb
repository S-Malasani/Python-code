# %%
# !pip install pandas_profiling
# !pip install sweetviz

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: how to read data from csv

import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Sample_Data/Salaries.csv")

# %%
df.shape
# Out:
# (78, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe(include="all")
# Out:
#         rank discipline        phd    service   sex         salary
# count     78         78  78.000000  78.000000    78      78.000000
# unique     3          2        NaN        NaN     2            NaN
# top     Prof          B        NaN        NaN  Male            NaN
# freq      46         42        NaN        NaN    39            NaN
# mean     NaN        NaN  19.705128  15.051282   NaN  108023.782051
# std      NaN        NaN  12.498425  12.139768   NaN   28293.661022
# min      NaN        NaN   1.000000   0.000000   NaN   57800.000000
# 25%      NaN        NaN  10.250000   5.250000   NaN   88612.500000
# 50%      NaN        NaN  18.500000  14.500000   NaN  104671.000000
# 75%      NaN        NaN  27.750000  20.750000   NaN  126774.750000
# max      NaN        NaN  56.000000  51.000000   NaN  186960.000000

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
# prompt: how to find na in the dataframe

df.isna().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-24-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-25-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.iloc[1:4]
# Out:
#    rank discipline  phd  service   sex  salary
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
df.iloc[1:4,2:4]
# Out:
#    phd  service
# 1   12        6
# 2   23       20
# 3   40       31

# %%
df.salary.mean()
# Out:
# 108023.78205128205

# %%
df.mean()
# Out:
# <ipython-input-29-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
# !pip install pandas_profiling
# !pip install sweetviz


Descriptive Statistics:
import pandas as pd
df=pd.read_csv("location.csv")
df.head()
df.columns
df.tail(20)
df.dtypes
df.describe()
df.info()
df.max()
df.min()
df.mean()
df.sex.value_counts()
df.std()
df.salary
df['salary']
df.iloc[3:6]
df.iloc[1:4,2:6]
df.iloc[:,4:6]
df.salary.mean()
df.salary.max()
df.salary.min()
df.salary.count()
df.groupby('rank').mean()
df[df.salary>120000]
df[df.sex=="Male"]
df.groupby('rank').mean()
df.groupby('rank').salary.mean()
df.groupby('rank')[['salary']].mean()
df[rows,columns]
df[start:stop-1,start:stop-1]


Visualization:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
os.getcwd()
os.chdir("C:\Users\Gfg\Desktop\geeks")
mtcars = pd.read_csv("/content/mtcars.csv")
pd.crosstab(mtcars.gear, mtcars.cyl)
pd.crosstab(mtcars.gear, mtcars.cyl).plot(kind='bar')
mtcars.gear.value_counts().plot(kind='bar')
plt.scatter(mtcars.mpg,mtcars.qsec)
mtcars.gear.value_counts().plot(kind="pie")
plt.hist(mtcars.mpg)
plt.boxplot(mtcars.mpg)


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")


tips=sns.load_dataset("tips")
tips

Univariate:
sns.distplot(tips.tip)
sns.stripplot(y='tip',data=tips, jitter=True)
sns.stripplot( x='day',y='tip',data=tips, jitter=True)
sns.swarmplot(x='day', y='tip', data=tips, hue='sex')
sns.boxplot(x='day', y='tip', data=tips)
sns.violinplot(x='day', y='tip', data=tips)

Bivariate:
sns.jointplot(x='total_bill', y='tip', data=tips)
sns.jointplot(x='total_bill', y= 'tip', data=tips,kind='kde')
sns.pairplot(tips)
sns.pairplot(tips, hue='sex')

Titanic
data=pd.read_csv('/content/train.csv')
data.Survived.value_counts()
data.groupby(data.Survived)['PassengerId'].count()
sns.barplot(x="Pclass", y="Survived", data=data);
survived=data.loc[data.Survived==1,'Age'].dropna()
sns.distplot(survived)
sns.pairplot(data.dropna());

grid = sns.FacetGrid(data, col='Survived', row='Pclass', size=2.4, aspect=1.5)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()


from scipy import stats
stats.norm.cdf(70, loc=60,scale=10)
mean = 60
standard deviation = 10
probability < 70


EDA:
Treat missing values

df.method()
dropna()                    #drop missing observations
dropna(how='all')           #drop observations where all the cells are na
dropna(axis=1,how='all')    #drop columns if all the values in the columns are na (axis =0 -> Rows,axis =1 -> Columns )
dropna(tresh=5)             #drop rows that contain less than 5 non missing values (less 5% data in the row ) or more than 5 missing values
fillna(0)                   #replace mising values with zeros
isnull()                    # returns True if the values is missing
notnull()                   # returns True for non missing values

#Scatter plot: Relations between 2 numerical variable

#Select rows or columns

#Select columns by name
df = pd.DataFrame(employees,
                  columns=['Name', 'Age',
                           'City', 'Salary'])

result = df[["Name", "Age", "Salary"]]

#select columns by index.  df.iloc[rows,columns]
result = df.iloc[:, [0,1,2]]


#select rows and columns by index
result = df.iloc[[2, 3, 5],
                [0, 1]]

#select rows by values
# Set index on a Dataframe
df.set_index("Name",
            inplace = True)

# Using the operator .loc[]
# to select multiple rows
result = df.loc[["Stuti", "Seema"]]


data.info()
# converting data from categorical to numeric and vice versa
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
data['Weather']=data['Weather'].astype('category')


#Count of duplicated rows
data[data.duplicated()].shape
data[data.duplicated()]
data_cleaned1=data.drop_duplicates()

#Drop Columns
data_cleaned2=data_cleaned1.drop('Temp C',axis=1)  #inplace=True


#rename the Solar column
data_cleaned3 = data_cleaned2.rename({'Solar.R': 'Solar'}, axis=1)


#Outlier Detection
# histogram of Ozone
data_cleaned3['Ozone'].hist()

#Box plot
data_cleaned3.boxplot(column=['Ozone'])

#Descriptive stat
data_cleaned3['Ozone'].describe()

#Bar plot
data['Weather'].value_counts().plot.bar()



#Missing values and Imputation
#heat map for the missing values
import seaborn as sns
cols = data_cleaned3.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours))

#print missing values
data_cleaned3[data_cleaned3.isnull().any(axis=1)].head()

#summary of missing values by columns
data_cleaned3.isnull().sum()



#Mean Imputation
mean = data_cleaned3['Ozone'].mean()
print(mean)

#fillinf the na with mean calculated in the above step
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(mean)


#Missing value imputation for categorical vlaue
#Get the object columns
obj_columns=data_cleaned3[['Weather']]
obj_columns.isnull().sum()
#Missing value imputation for categorical vlaue
obj_columns=obj_columns.fillna(obj_columns.mode().iloc[0])
obj_columns.isnull().sum()
#Join the data set with imputed object dataset
data_cleaned4=pd.concat([data_cleaned3,obj_columns],axis=1)
data_cleaned4.isnull().sum()



#Sctter plot and correlation analysis
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(data_cleaned3)


#heat map
plt.figure(figsize=(10, 7))
sns.heatmap(data_cleaned3.corr(), annot=True)


#Creating dummy variable for Weather column
data_cleaned4=pd.get_dummies(data,columns=['Weather'])
data_cleaned4=data_cleaned4.dropna()


#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

array = data_cleaned3.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])

# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

array = data_cleaned4.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])



#Left, right joines in the data based on different scenarios
import pandas as pd
df1=pd.read_excel("/content/Dummy_course_data.xlsx", sheet_name="Fees")
df2=pd.read_excel("/content/Dummy_course_data.xlsx", sheet_name="Discounts")

#DataFrame.merge(left,right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
df3=pd.merge(df1,df2) #by default inner join

df4=pd.merge(df1, df2, how='outer')

df5=pd.merge(df1, df2, how='left')

df6=pd.merge(df1, df2, how='right')

df7=pd.merge(df1, df2, how='left', left_on='Course', right_on='Course')

#pandas.concat(objs, *, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=True)

df8=pd.concat([df1, df2])
#df8=pd.concat([df1, df2], axis=0)

df9=pd.concat([df1,df2], axis=1)

df10=pd.concat([df1,df2], axis=1,
          keys = ["df1_data","df2_data"])


# Rearranging the columns names
df3.columns
#Index(['Course', 'Country', 'Fee_USD', 'Discount_USD'], dtype='object')
cols=list(df3.columns.values)
cols
df11 = df3[['Country','Course', 'Fee_USD', 'Discount_USD']]



#Speed up the EDA process
import pandas as pd
import numpy as np
import pandas_profiling as pp
import sweetviz as sv
import matplotlib.pyplot as plt
# %matplotlib inline


EDA_report = pp.ProfileReport(data)
EDA_report.to_file(output_file='report.html')

sweet_report = sv.analyze(data)
sweet_report.show_html('weather_report.html')



#Simple linear regression
import pandas as pd
data =pd.read_csv("NewpaperData.csv")
data.head()
data.info()
data.corr()
import seaborn as sns
sns.distplot(data['daily'])

#fitting linear regression
import statsmodel.formula.api as smf
model= smf.ols("sunday~daily", data=data).fit()

#to plot regression line
sns.regplot(x="daily", y="sunday", data=data)

#coefficient
model.params

#t-values and p-values
print(model.tvalues, '\n', model.pvalues)

#R square and Adj R square
(model.rsquared,model.rsquared_adj)


#prediting for new data points 200 and 300 daily circulation
newdata=pd.Series([200,300])
data_pred=pd.DataFrame(newdata, columns=['daily'])
model.predict(data_pred)



#Multi Linear regression
#refer Multi Linera Regression.ipynb for indepth modelling

final_model= smf.ols('MPG~VOL+SP+HP',data = car4).fit()
(final_model.rsquared,final_model.aic)
new_data=pd.DataFrame({'HP':40,"VOL":95,"SP":102,"WT":35},index=[1])
final_model.predict(new_data)



#Logistic regression

import pandas as pd
from sklear.linear_model import LogisticRegression

df.info()
df=df.dropna()

#Dividing dependent and independent variables
X=df.iloc[:,1:]
Y=df.iloc[:,0]

Model = LogisticsRegression()
Model.fit(X,Y)

y_pred=Model.predict(X)

y_pred_df= pd.DataFrame({'actual':Y,'Predicted_prob': Model.predict(X)})

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y,y_pred)
print(confusion_matrix)

from sklearn.metrics import classification_report
print(classification_report(Y,y_pred))

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
fpr,tpr,thresholds = roc_curve(Y, Model.predict_proba(X)[:,1])

auc=roc_auc_score(Y,y_pred)

# to print auc graph
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red', label='logit model ( area  = %0.2f)'%auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')



#Hierarchical clustering
import scipy.cluster.hierarchy as schema
from sklear.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

#Normalzation function
def norm_func(i):
    x=(i-i.min())/(i.max()-i.min())
    return(x)

#Normalizing data fram (considering the numerical pasrt of data)
df_norm= norm_finc(df.iloc[;.1:])

#creta dendrogram which help us in finding optimal number of clusters for the data
dendrogram = sch.dendrogram(sch.linkage(df_norm,method='single))'))

#create cluster algo
hc=AgglomerativeClustering(n_cluster=4, affinity='eucliden', linkage 'single')

#apply the algo on the data
y_fhc=hc.fit_predict(df_norm)
Clusters=pd.DataFram(y_hc,columns=['clusters'])

df_norm['h_clusterid']=Clusters

df['h_clusyerid']= Clusters




#Kmeans clustering
from matplotlib import pyplot as plt
from sklear.cluster import KMeans

#Univ data set
#Noralzation function
from sklearn.preprocessing import StandardScaler
scalar= StandardScaler()
scaled_Univ_df= sclar.fit_transform(Univ.iloc[:,1:])

# How to find optimum number of  cluster  K Value
#The K-means algorithm aims to choose centroids that minimise the inertia, or within-cluster sum-of-squares criterion:
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_Univ_df)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()


#Build Cluster algorithm
from sklearn.cluster import KMeans
clusters_new = KMeans(4, random_state=42)
clusters_new.fit(scaled_Univ_df)

clusters_new.labels_

#Assign clusters to the data set
Univ['clusterid_new'] = clusters_new.labels_


Univ.groupby('clusterid_new').agg(['mean']).reset_index()
Univ




#DBSCAN
from sklear.cluster import DBSCAN
from sklearn.preprocessing import SrandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# drop unwanted labels and null values and subset categorical variables
# covert the datafram in to arrays and remove the column names to standardize the values

#Standardize features by removing the mean and scaling to unit variance using StandardScaler
array=df.values


s=StandarScaler().fit(array)
X=s.transform(array)

#another way of code for standardizing the values nothing but the z score -3 to 3
scaler = StandardScaler()
X= scaler.fit_transform(array)
X


dbscan=DBSCAN(eps=1,min_samples=6)
dbscan.fit(X)

#Noisy samples are given the label -1.
dbscan_labels_
cl=pd.DataFrame(dbscan.labels_, columns=['cluster'])

df=pd.concat([df,cl],axis=1)
df


#Association rules Apriori algorithm
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
# conda install -c conda-forge mlxtend
titanic = pd.read_csv("Titanic.csv")
titanic.head()

#pre processing As the data is not in transaction formation We are using transaction Encoder
df=pd.get_dummies(titanic)
df.head()

#Apriori Algorithm
frequent_itemsets = apriori(df, min_support=0.1, use_colnames=True)
frequent_itemsets

#Rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
rules


#An leverage value of 0 indicates independence. Range will be [-1 1]
# A high conviction value means that the consequent is highly depending on the antecedent and range [0 inf]

rules.sort_values('lift',ascending = False)[0:20]
rules[rules.lift>1]



#Recommendation System
import pandas as pd
import numpy as np

movies_df.info()
len(movies_df.userId.unique())

#changing the data in wide columns
user_movies_df= movies_df.pivot(index='userId',
                                columns='movie',
                                values='rating').reset_index(drop=True)

user_movies_df.index = movies_df.userId.unique()

#Impute those NaNs with 0 values
user_movies_df.fillna(0, inplace=True)


#Calculating Cosine Similarity between Users
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine, correlation

user_sim = 1 - pairwise_distances( user_movies_df.values,metric='cosine')

#Store the results in a dataframe
user_sim_df = pd.DataFrame(user_sim)

#Set the index and column names to user ids
user_sim_df.index = movies_df.userId.unique()
user_sim_df.columns = movies_df.userId.unique()


#Most Similar Users
user_sim_df.idxmax(axis=1)[0:5]


movies_df[(movies_df['userId']==6) | (movies_df['userId']==168)]


user_1=movies_df[movies_df['userId']==6]
user_2=movies_df[movies_df['userId']==11]

pd.merge(user_1,user_2,on='movie',how='outer')



#PCA
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale

# Considering only numerical data
uni.data = uni.iloc[:,1:]
uni.data.head()
# Converting into numpy array
UNI = uni.data.values
# Normalizing the numerical data
uni_normal = scale(UNI)

#Applying PCA
pca = PCA()
pca_values = pca.fit_transform(uni_normal)

#n components =6, num pca's that we want to use
pca = PCA(n_components = 6)
pca_values = pca.fit_transform(uni_normal)

#pca_values=PCA(n_components=6).fit_transfor(uni_normal)


# The amount of variance that each PCA explains is , this will help us determine the n_components value
var = pca.explained_variance_ratio_
var

# Cumulative variance
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1

pca.components_

# Variance plot for PCA components obtained
plt.plot(var1,color="red")


# plot between PCA1 and PCA2
x = pca_values[:,0:1]
y = pca_values[:,1:2]
#z = pca_values[:2:3]
plt.scatter(x,y)

finalDf = pd.concat([pd.DataFrame(pca_values[:,0:2],columns=['pc1','pc2']), uni[['Univ']]], axis = 1)

#this graph will help to visually classify, cluster or group the data points
import seaborn as sns
sns.scatterplot(data=finalDf,x='pc1',y='pc2',hue='Univ')




#t-SNE

# !pip install bioinfokit

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from bioinfokit.visuz import cluster

# load data
filename = '/content/TSNE_data.csv'
dataframe = pd.read_csv(filename)

# Split-out validation dataset
array = dataframe.values
# separate array into input and output components
X = array[:,1:]
Y = array[:,0]

#TSNE visualization
from bioinfokit.visuz import cluster

data_tsne = TSNE(n_components=2).fit_transform(X)
cluster.tsneplot(score=data_tsne)

# get a list of categories
color_class = dataframe['diagnosis'].to_numpy()
cluster.tsneplot(score=data_tsne, colorlist=color_class, legendpos='upper right',legendanchor=(1.15, 1))

#Plot will be stored in the default directory

data_tsne


Pacakage-> Module -> Method/Function
### Decision trees
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklear.model_selection import train_test_split
from sklearn.tree import DecesionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

iris = pd.read_csv('/content/iris.csv',index_col=0)


#Encoding the y variable to numerics
label_encoder = preprocessing.LabelEncoder()
iris['Species']= label_encoder.fit_transform(iris['Species'])

#splitting x and y variables
x=iris.iloc[:,0:4]
y=iris['Species']

# Splitting data into training and testing data set
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=40)

#Building model
#Building Decision Tree Classifier using Entropy Criteria
model = DecisionTreeClassifier(criterion = 'entropy',max_depth=3)
model.fit(x_train,y_train)

#PLot the decision tree
tree.plot_tree(model);

#Predicting on test data
preds = model.predict(x_test) # predicting on test data set
pd.Series(preds).value_counts() # getting the count of each category

# getting the 2 way table to understand the correct and wrong predictions
pd.crosstab(y_test,preds)

# Accuracy
np.mean(preds==y_test)

#Model accuracy
model.score(x_test,y_test)



#Building Decision Tree Classifier (CART) using Gini Criteria
from sklearn.tree import DecisionTreeClassifier
model_gini = DecisionTreeClassifier(criterion='gini', max_depth=3)
model_gini.fit(x_train,y_train)

#Prediction and computing the accuracy
pred=model.predit(x_test)
np.mean(preds==y_test)





#Decision Tree Regression Example
from sklearn.tree import DecisionTreeRegressor

#spliting x & y variables, considering first 3 columns are x and 4th column as y variable for prediting
array = iris.values
X = array[:,0:3]
y = array[:,3]

#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

#regression model building
model = DecisionTreeRegressor()
model.fit(X_train, y_train)

#Find the accuracy
model.score(X_test,y_test)




#Label Encoder

from sklearn.preprocessing import LabelEncoder
import pandas as pd

#applying lable encoder
labelencoder = LabelEncoder()
data['Species']=labelencoder.fit_transform(data.iloc['Species'])
#alternative way
data1.Species=labelencoder.fit_transform(data1.Species)


#One Hot Encoding
import pandas as pd
data_encoded=pd.get_dummies(data)




#Isolation forest
from sklearn.ensemble import IsolationForest

#need to convet the data in to one hot encoding to apply Isolation forest
data_encoded=pd.get_dummies(data)

# training the model
clf = IsolationForest(random_state=10,contamination=.01)
clf.fit(data_encoded)

# predictions
y_pred_outliers = clf.predict(data_encoded)

#adding scores to the dataset
data_encoded['scores']=clf.decision_function(data_encoded)

#adding anomaly to the dataset
data_encoded['anomaly']=clf.predict(data_encoded.iloc[:,0:7])

#Print the outlier data points
data_encoded[data_encoded['anomaly']==-1]






#PPS score
#install the package
# !pip install ppscore

#pps.score(df, "feature_column", "target_column")  syntax
pps.score(data, "Sepal.Length", "Petal.Length")

#calculate the whole PPS matrix
pps.matrix(data)


#Feature Engineering
# Feature Extraction with Univariate Statistical Tests (Chi-squared for classification)
from pandas import read_csv
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# load data
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(X)

#For regression: f_regression, mutual_info_regression
#For classification: chi2, f_classif, mutual_info_classif


# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
model = LogisticRegression(max_iter=400)
rfe = RFE(model, 3)
fit = rfe.fit(X, Y)

#Num Features:
fit.n_features_

#Selected Features:
fit.support_

# Feature Ranking:
fit.ranking_



# Feature Importance with Extra Trees Classifier
from pandas import read_csv
from sklearn.tree import  DecisionTreeClassifier
# load data
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
model = DecisionTreeClassifier()
model.fit(X, Y)
print(model.feature_importances_)




########### Model validation Techniques
# Evaluate using a train and a test set
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
test_size = 0.33
seed = 7
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size,random_state=seed)
model = LogisticRegression()
model.fit(X_train, Y_train)
result = model.score(X_test, Y_test)



# Evaluate using Cross Validation
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
num_folds = 10
seed = 7
kfold = KFold(n_splits=num_folds, random_state=seed)
model = LogisticRegression(max_iter=400)
results = cross_val_score(model, X, Y, cv=kfold)
results.mean()*100.0
results.std()*100.0



# Evaluate using Leave One Out Cross Validation
from pandas import read_csv
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
loocv = LeaveOneOut()
model = LogisticRegression(max_iter=300)
results = cross_val_score(model, X, Y, cv=loocv)
results.mean()*100.0
results.std()*100.0



# Bagged Decision Trees for Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
seed = 7

kfold = KFold(n_splits=10, random_state=seed)
cart = DecisionTreeClassifier()
num_trees = 100
model = BaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=seed)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())



# Random Forest Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

X = array[:,0:8]
Y = array[:,8]
num_trees = 100
max_features = 3
kfold = KFold(n_splits=10, random_state=7)
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())




# AdaBoost Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values

X = array[:,0:8]
Y = array[:,8]

num_trees = 10
seed=7
kfold = KFold(n_splits=10, random_state=seed)
model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())




# Stacking Ensemble for Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
kfold = KFold(n_splits=10, random_state=7)

# create the sub models
estimators = []
model1 = LogisticRegression(max_iter=500)
estimators.append(('logistic', model1))
model2 = DecisionTreeClassifier()
estimators.append(('cart', model2))
model3 = SVC()
estimators.append(('svm', model3))

# create the ensemble model
ensemble = VotingClassifier(estimators)
results = cross_val_score(ensemble, X, Y, cv=kfold)
print(results.mean())




#KNN
# KNN Classification
from pandas import read_csv
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:, 0:8]
Y = array[:, 8]
num_folds = 10
kfold = KFold(n_splits=10)

model = KNeighborsClassifier(n_neighbors=17)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())



# Grid Search for Algorithm Tuning
import numpy
from pandas import read_csv
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:, 0:8]
Y = array[:, 8]

n_neighbors = numpy.array(range(1,40))
param_grid = dict(n_neighbors=n_neighbors)

model = KNeighborsClassifier()
grid = GridSearchCV(estimator=model, param_grid=param_grid)
grid.fit(X, Y)

print(grid.best_score_)
print(grid.best_params_)



#Visualizing the CV results
import matplotlib.pyplot as plt
# %matplotlib inline
# choose k between 1 to 41
k_range = range(1, 41)
k_scores = []
# use iteration to caclulator different k in models, then return the average accuracy based on the cross validation
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, Y, cv=5)
    k_scores.append(scores.mean())
# plot to see clearly
plt.plot(k_range, k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
plt.show()





### SVM

# SVM Classification
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler

from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score

filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pd.read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3)
X_train_raw.shape, y_train.shape, X_test_raw.shape, y_test.shape

#Grid search CV
clf = SVC()
param_grid = [{'kernel':['rbf'],'gamma':[50,5,10,0.5],'C':[15,14,13,12,11,10,0.1,0.001] }]
gsv = GridSearchCV(clf,param_grid,cv=10)
gsv.fit(X_train,y_train)

gsv.best_params_ , gsv.best_score_

clf = SVC(C= 15, gamma = 50)
clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)






##############Ridge Lasso ElasticNet
